# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import requests
import time
import re
import os

# %%
def check_date():
    dir_list = os.listdir(dir_path)
    return len(dir_list)

def open_browser(url):
    browser = webdriver.Chrome()
    browser.implicitly_wait(5)
    browser.get(url)
    
    time.sleep(5)

    return browser

# def login():
#     try:
#         #browser.find_element_by_xpath("//*[contains(text(), '登入')]").click()

#         #time.sleep(1)

#         user = browser.find_element_by_xpath("//input[@name='search']")
#         user.send_keys("Abelia chinensis")
#         #password = browser.find_element_by_xpath("//input[@type='password']")
#         #password.send_keys("Waynesu0")
        
#         #login = browser.find_elements_by_xpath("//*[contains(text(), '送出')]")
#         login = browser.find_elements_by_xpath("//input[@name='enter2']").click()
#         print(login)
#         #login[-1].click()

#         #time.sleep(3)

#     except:
#         print("error")
#         browser.quit()
        
def get_url():
    #browser.find_element_by_xpath("//*[contains(text(), '登入')]").click()

    #time.sleep(1)

    user = browser.find_element_by_xpath("//input[@name='search']")
    user.send_keys("Abelia chinensis")
    #password = browser.find_element_by_xpath("//input[@type='password']")
    #password.send_keys("Waynesu0")

    #login = browser.find_elements_by_xpath("//*[contains(text(), '送出')]")
    print(browser.find_elements_by_xpath("//input[@name='enter2']"))
    browser.find_elements_by_xpath("//input[@name='enter2']")[0].click()
    #login[-1].click()
    login = browser.find_elements_by_xpath("//*[@id='center']/table/tbody/tr[2]/td[2]/a")[0]
    #for link in browser.find_elements_by_xpath("//*[@id='center']/table/tbody/tr[0]/td[1]/a"):
        #print(link)
    print(login)


    time.sleep(3)

    #print("error")
    #browser.quit()

'''
def download_file(day):
    while(day):
        target_day_url = url_prefix + str(day)
        browser.get(target_day_url)
        unopen = browser.find_elements_by_xpath("//*[contains(text(), '題目尚未釋放')]")
        if(unopen):
            break
        else:
            soup = BeautifulSoup(browser.page_source, 'lxml')
            a_element = soup.find("a", {'href':re.compile("//pycrawler-fileentity.*")})
            #print("a_element",a_element)

            pdfURL = a_element['href']
            pdfURL = "https:" + pdfURL

            r = requests.get(pdfURL, stream=True)
            select_day = 'D' + str(day)
            select_day = "//*[contains(text(), 'D%s')]"%(day)
            print(select_day)
            
            DirName = browser.find_elements_by_xpath(select_day)[1].text
            if "/" in DirName:
                DirName = DirName.replace("/","-")
            #DirName = "D" + str(day)
            print("DirName",DirName)
            fileName = DirName + ".pdf"
            Dir = os.path.join(dir_path, DirName)
            fileName = os.path.join(Dir, fileName)
            os.makedirs(Dir, exist_ok=True)

            with open(fileName, 'wb') as f:
                f.write(r.content)

            hwURL = hwURL_prefix + DirName
            hw_name = DirName + ".7z"
            hw = os.path.join(Dir, hw_name)

            r = requests.get(hwURL, stream=True)
            with open(hw, 'wb') as f:
                f.write(r.content)

        day += 1
'''
    
#dir_path = "D://GDbackup/cupoy/1st-PyCrawlerMarathon_data"
#day = "1"
url_prefix = "http://tai2.ntu.edu.tw/PlantInfo.php"
#hwURL_prefix = "https://pycrawler.cupoy.com/HomeworkAction.do?op=getHomeworkFileComb&hwid="
#url = url_prefix + day

browser = open_browser(url_prefix)
get_url()

#day = check_date()
#download_file(day)

print("finish")

browser.quit()
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="a0010c18aba2d846a6274b89731467d0", element="64c81201-515b-4278-88cb-78cd50ea0f28")>]
# <selenium.webdriver.remote.webelement.WebElement (session="a0010c18aba2d846a6274b89731467d0", element="b194ea4a-ad53-4f99-9819-d3e5b68bcbf7")>
# finish

# %%
browser = open_browser(url_prefix)


user = browser.find_element_by_xpath("//input[@name='search']")
user.send_keys("Abelia chinensis")
#password = browser.find_element_by_xpath("//input[@type='password']")
#password.send_keys("Waynesu0")

#login = browser.find_elements_by_xpath("//*[contains(text(), '送出')]")
print(browser.find_elements_by_xpath("//input[@name='enter2']"))
browser.find_elements_by_xpath("//input[@name='enter2']")[0].click()
#login[-1].click()
login = browser.find_elements_by_xpath("//*[@id='center']/table/tbody")
print("000")
print(login)
print("000")
print("....",len(login))
for i in range(2,10,1):
    try:
        print(i)
        print(browser.find_elements_by_xpath("//*[@id='center']/table/tbody/tr[%d]/td[2]/a"%(i))[0].get_attribute("href"))
    except:
        break
#print(browser.find_elements_by_xpath("//*[@id='center']/table/tbody/tr[2]/td[2]/a")[0].get_attribute("href"))
#for link in browser.find_elements_by_xpath("//*[@id='center']/table/tbody/tr[0]/td[1]/a"):
print(login)
for i in login:
    print(">>>>")
    print(i)


time.sleep(3)
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="7fc31e3a4cf15cad097a57d25c7c6481", element="ea32c88b-14d8-46bd-872a-0b305e9f49c0")>]
# 000
# [<selenium.webdriver.remote.webelement.WebElement (session="7fc31e3a4cf15cad097a57d25c7c6481", element="5176a7f9-6bf2-49cd-8a59-503333370331")>]
# 000
# .... 1
# 2
# http://tai2.ntu.edu.tw/PlantInfo/species-name.php?code=534%20001%2002%201
# 3
# http://tai2.ntu.edu.tw/PlantInfo/species-name.php?code=534%20001%2002%201
# 4
# [<selenium.webdriver.remote.webelement.WebElement (session="7fc31e3a4cf15cad097a57d25c7c6481", element="5176a7f9-6bf2-49cd-8a59-503333370331")>]
# >>>>
# <selenium.webdriver.remote.webelement.WebElement (session="7fc31e3a4cf15cad097a57d25c7c6481", element="5176a7f9-6bf2-49cd-8a59-503333370331")>

# %%
for i in login:
    print(i.text)
# Out:
# Family Name Chinese name Status
# Caprifoliaceae  忍冬科 Abelia chinensis 台灣糯米條 Synonym
# Caprifoliaceae  忍冬科 Abelia chinensis var. ionandra 台灣糯米條 Accepted

# %%
len(login[0].text.split("\n"))
# Out:
# 3

# %% [markdown]
# ## 一、簡單的爬蟲
# ### 1.web_scrapy hello world
# request,response 200 意思是正常,不正常的話回傳404,防火牆擋掉500

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "http://pythonscraping.com/pages/page1.html"
html = requests.get(url)
html
# Out:
# <Response [200]>

# %% [markdown]
# ### 查content

# %%
html.content
# Out:
# b'<html>\n<head>\n<title>A Useful Page</title>\n</head>\n<body>\n<h1>An Interesting Title</h1>\n<div>\nLorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.\n</div>\n</body>\n</html>\n'

# %%
html.text
# Out:
# '<html>\n<head>\n<title>A Useful Page</title>\n</head>\n<body>\n<h1>An Interesting Title</h1>\n<div>\nLorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.\n</div>\n</body>\n</html>\n'

# %% [markdown]
# ### 2.解析html，使用套件beautifulsoup
# 把斜線，空白之類的去除使用strip

# %%
soup = BeautifulSoup(html.content)
soup.select("h1")[0].text.strip()
# Out:
# C:\Users\nien\Anaconda3\envs\tensorflow-gpu\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Users\nien\Anaconda3\envs\tensorflow-gpu\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# 'An Interesting Title'

# %% [markdown]
# 練習，爬wiki_pedia

# %%
from bs4 import BeautifulSoup
import requests
url = "https://en.wikipedia.org/wiki/Python_(programming_language)"
html = requests.get(url)
soup = BeautifulSoup(html.content)
for i in soup.select("p"):
    print(i.text)
# Out:
# Python is an interpreted high-level programming language for general-purpose programming. Created by Guido van Rossum and first released in 1991, Python has a design philosophy that emphasizes code readability, notably using significant whitespace. It provides constructs that enable clear programming on both small and large scales.[27] In July 2018, Van Rossum stepped down as the leader in the language community after 30 years.[28][29]
#
# Python features a dynamic type system and automatic memory management. It supports multiple programming paradigms, including object-oriented, imperative, functional and procedural, and has a large and comprehensive standard library.[30]
#
# Python interpreters are available for many operating systems. CPython, the reference implementation of Python, is open source software[31] and has a community-based development model, as do nearly all of Python's other implementations. Python and CPython are managed by the non-profit Python Software Foundation.
# ...

# %% [markdown]
# ## 二、apple_diary實戰

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
iAstro_name = {"0":"牡羊座","1":"金牛座","2":"雙子座","3":"巨蟹座","4":"獅子座","5":"處女座",
              "6":"天秤座","7":"天蠍座","8":"射手座","9":"魔羯座","10":"水瓶座","11":"雙魚座"}

title = ["幸運數字","今日吉時","幸運顏色","開運方位","幸運星座","整體評分",
         "整體說明","愛情評分","愛情說明","事業評分","事業說明","財運評分","財運說明"]

dict_result = {}

date = "2020-02-18"
#iAstro = "0"

# %%
def web_scrapy(date,iAstro):
    temp_list = []
    url = "http://astro.click108.com.tw/daily_%d.php?iAstro=%d&iAcDay=%s"%(int(iAstro),int(iAstro),date)
    res = requests.get(url)
    #res.content
    soup = BeautifulSoup(res.text, "lxml")
    #print(soup.text)
    #print("日期 :",date)
    print("星座 :",iAstro_name[iAstro])
    #print("幸運數字 :",soup.findAll("div", class_="LUCKY")[0].text.split()[0])
    #print("今日吉時 :",soup.findAll("div", class_="LUCKY")[1].text.split()[0])
    #print("幸運顏色 :",soup.findAll("div", class_="LUCKY")[2].text.split()[0])
    #print("開運方位 :",soup.findAll("div", class_="LUCKY")[3].text.split()[0])
    #print("幸運星座 :",soup.findAll("div", class_="LUCKY")[4].text.split()[0])
    print("-----------")
    #dict_result=pd.DataFrame({"":title})

    for i,j in enumerate(soup.findAll("div", class_="LUCKY")):
        print(j.text.split()[0])
        temp_list.append(j.text.split()[0])

    for i,j in enumerate(soup.select("div.TODAY_CONTENT > p")):    
        if (i)%2 == 0:
            print(j.text[4:-1])
            temp_list.append(j.text[4:-1])
        else:
            print(j.text)
            temp_list.append(j.text)
            print()
    return temp_list

dict_result=pd.DataFrame({"":title})
for i in range(0,12,1):
    temp_list = web_scrapy(date,str(i))
    dict_result[iAstro_name[str(i)]] =  temp_list    
        
dict_result.to_csv("%s.csv"%(date),encoding="utf_8_sig",index=0)
# Out:
# 日期 : 2020-02-17
# 星座 : 牡羊座
# 幸運數字 : 8
# 今日吉時 : 蕃茄紅
# 幸運顏色 : 東北方向
# 開運方位 : 1:00-3:00pm
# 幸運星座 : 水瓶座
# -----------
# 8
# 蕃茄紅
# 東北方向
# 1:00-3:00pm
# 水瓶座
# ★★★★★
# 今天的工作能發揮出你的才華，可望得到老闆的賞識。已婚者與另一半吃頓富有情調的晚餐，可為平淡的感情生活製造激情，讓心與心更加貼近，愛情有如沐春風的感覺。學習吸收能力很強，適合英語、文科類的學習，會有事半功倍的效果。
#
# ★★★★☆
# 已有心上人的單身者，請同事協助撮合你的戀情吧！戀愛中人，今日可得到情人的關心與助力。
#
# ★★★★☆
# 事業運頗優，有利於業務工作者，在外頭奔波一番多能有正面收穫；今日有機會得到貴人從中協助。
#
# ★★★★☆
# 金錢活動頻繁的一天，呈現有進有出的雙重跡象，例如：金錢入帳後又把錢轉手出去。
#
# 日期 : 2020-02-17
# 星座 : 金牛座
# 幸運數字 : 5
# 今日吉時 : 咖啡棕
# 幸運顏色 : 西南方向
# 開運方位 : 4:00-6:00pm
# 幸運星座 : 雙魚座
# -----------
# 5
# 咖啡棕
# 西南方向
# 4:00-6:00pm
# 雙魚座
# ★★★★☆
# 單身者今天會有不錯的異性緣，且在宴會或聚會上得到更明晰的顯露；搖擺不定會使你失去更多的投資契機，其實今天是個不錯的投資時機喔！耐住性子，你的進步會比他人來得更明顯。
#
# ★★★★★
# 戀情浪漫、熱烈。感覺相互都離不開對方，即使需要在其它方面做出一點犧牲也樂意。
#
# ★★★☆☆
# 事業運普通，顯得忙碌，事情接二連三的來，應付起來有些吃力。
#
# ★★★☆☆
# 容易把錢花在朋友身上，但感覺很值得。
#
# 日期 : 2020-02-17
# 星座 : 雙子座
# 幸運數字 : 3
# 今日吉時 : 冷泉藍
# 幸運顏色 : 正西方向
# 開運方位 : 6:00-8:00am
# 幸運星座 : 雙子座
# -----------
# 3
# 冷泉藍
# 正西方向
# 6:00-8:00am
# 雙子座
# ★★☆☆☆
# ...

# %%
dict_result.to_csv("%s.csv"%(date),encoding="utf_8_sig",index=0)

# %%
dict_result.to_json("%s.csv"%(date))

# %%
def web_scrapy(date,iAstro):
    url = "http://astro.click108.com.tw/daily_%d.php?iAstro=%d&iAcDay=%s"%(int(iAstro),int(iAstro),date)
    res = requests.get(url)
    #res.content
    soup = BeautifulSoup(res.text, "lxml")
    #print(soup.text)
    print("日期 :",date)
    print()
    print("幸運數字 :",soup.findAll("div", class_="LUCKY")[0].text.split()[0])
    print("今日吉時 :",soup.findAll("div", class_="LUCKY")[1].text.split()[0])
    print("幸運顏色 :",soup.findAll("div", class_="LUCKY")[2].text.split()[0])
    print("開運方位 :",soup.findAll("div", class_="LUCKY")[3].text.split()[0])
    print("幸運星座 :",soup.findAll("div", class_="LUCKY")[4].text.split()[0])
    print("-----------")
    for i,j in enumerate(soup.select("div.TODAY_CONTENT > p")):
        print(j.text)
        if (i+1)%2 == 0:
            print()
    return

# %%
for i in range(0,1,1):
    web_scrapy(date,i)
# Out:
# 日期 : 2020-02-17
#
# 幸運數字 : 8
# 今日吉時 : 蕃茄紅
# 幸運顏色 : 東北方向
# 開運方位 : 1:00-3:00pm
# 幸運星座 : 水瓶座
# -----------
# 整體運勢★★★★★：
# 今天的工作能發揮出你的才華，可望得到老闆的賞識。已婚者與另一半吃頓富有情調的晚餐，可為平淡的感情生活製造激情，讓心與心更加貼近，愛情有如沐春風的感覺。學習吸收能力很強，適合英語、文科類的學習，會有事半功倍的效果。
#
# 愛情運勢★★★★☆：
# 已有心上人的單身者，請同事協助撮合你的戀情吧！戀愛中人，今日可得到情人的關心與助力。
#
# 事業運勢★★★★☆：
# 事業運頗優，有利於業務工作者，在外頭奔波一番多能有正面收穫；今日有機會得到貴人從中協助。
#
# 財運運勢★★★★☆：
# 金錢活動頻繁的一天，呈現有進有出的雙重跡象，例如：金錢入帳後又把錢轉手出去。
#
# 日期 : 2020-02-17
#
# 幸運數字 : 5
# 今日吉時 : 咖啡棕
# 幸運顏色 : 西南方向
# 開運方位 : 4:00-6:00pm
# 幸運星座 : 雙魚座
# -----------
# 整體運勢★★★★☆：
# 單身者今天會有不錯的異性緣，且在宴會或聚會上得到更明晰的顯露；搖擺不定會使你失去更多的投資契機，其實今天是個不錯的投資時機喔！耐住性子，你的進步會比他人來得更明顯。
#
# 愛情運勢★★★★★：
# 戀情浪漫、熱烈。感覺相互都離不開對方，即使需要在其它方面做出一點犧牲也樂意。
#
# 事業運勢★★★☆☆：
# 事業運普通，顯得忙碌，事情接二連三的來，應付起來有些吃力。
#
# 財運運勢★★★☆☆：
# 容易把錢花在朋友身上，但感覺很值得。
#
# 日期 : 2020-02-17
#
# 幸運數字 : 3
# 今日吉時 : 冷泉藍
# 幸運顏色 : 正西方向
# 開運方位 : 6:00-8:00am
# 幸運星座 : 雙子座
# -----------
# 整體運勢★★☆☆☆：
# 想法頗多，會有不安全感，對身邊的人、事、物感覺敏銳，稍有風吹草動你都會有所察覺，工作也易受到影響。做好自己的事情就好，別想得太複雜。有什麼心事、壓力可以與父母長輩或另一半交流，會讓你很快釋然。
#
# 愛情運勢★★★☆☆：
# ...

# %% [markdown]
# ## 三、pandas,自帶爬蟲

# %%
import requests
import pandas as pd

# %%
url = "https://rate.bot.com.tw/xrt?Lang=zh-TW"
data = pd.read_html(url)
data[0]
# Out:
#                         幣別              現金匯率 Unnamed: 3_level_0    即期匯率  \
#         Unnamed: 0_level_1     本行買入     本行賣出               本行買入    本行賣出
# 0       美金 (USD)  美金 (USD)   30.415   31.105             30.785  30.885
# 1       港幣 (HKD)  港幣 (HKD)    3.771    3.987              3.907   3.967
# 2       英鎊 (GBP)  英鎊 (GBP)    38.96    41.08              39.96   40.38
# 3       澳幣 (AUD)  澳幣 (AUD)    22.08    22.86              22.35   22.58
# 4   加拿大幣 (CAD)  加拿大幣 (CAD)    22.82    23.73              23.21   23.43
# 5   新加坡幣 (SGD)  新加坡幣 (SGD)    21.85    22.76              22.34   22.52
# 6   瑞士法郎 (CHF)  瑞士法郎 (CHF)    29.87    31.07              30.53   30.82
# 7       日圓 (JPY)  日圓 (JPY)   0.2623   0.2751             0.2696  0.2736
# 8     南非幣 (ZAR)  南非幣 (ZAR)        -        -               2.13    2.21
# 9     瑞典幣 (SEK)  瑞典幣 (SEK)     3.02     3.54               3.36    3.46
# 10      紐元 (NZD)  紐元 (NZD)    20.52    21.37               20.9    21.1
# ...

# %% [markdown]
# ### 切片 (row/column) 含頭不含尾

# %%
#data_clean = data[0].iloc[:,:5]+data[0].iloc[:,7:11]
data_clean = data[0].iloc[:,:5]
data_clean
# Out:
#                         幣別              現金匯率 Unnamed: 3_level_0    即期匯率
#         Unnamed: 0_level_1     本行買入     本行賣出               本行買入    本行賣出
# 0       美金 (USD)  美金 (USD)   30.415   31.105             30.785  30.885
# 1       港幣 (HKD)  港幣 (HKD)    3.771    3.987              3.907   3.967
# 2       英鎊 (GBP)  英鎊 (GBP)    38.96    41.08              39.96   40.38
# 3       澳幣 (AUD)  澳幣 (AUD)    22.08    22.86              22.35   22.58
# 4   加拿大幣 (CAD)  加拿大幣 (CAD)    22.82    23.73              23.21   23.43
# 5   新加坡幣 (SGD)  新加坡幣 (SGD)    21.85    22.76              22.34   22.52
# 6   瑞士法郎 (CHF)  瑞士法郎 (CHF)    29.87    31.07              30.53   30.82
# 7       日圓 (JPY)  日圓 (JPY)   0.2623   0.2751             0.2696  0.2736
# 8     南非幣 (ZAR)  南非幣 (ZAR)        -        -               2.13    2.21
# 9     瑞典幣 (SEK)  瑞典幣 (SEK)     3.02     3.54               3.36    3.46
# 10      紐元 (NZD)  紐元 (NZD)    20.52    21.37               20.9    21.1
# ...

# %%
data_clean.columns = ["幣別","現今匯率-本行買入","現今匯率-本行賣出","即期匯率-本行買入","即期匯率-本行買出"]
data_clean
# Out:
#                         幣別 現今匯率-本行買入 現今匯率-本行賣出 即期匯率-本行買入 即期匯率-本行買出
# 0       美金 (USD)  美金 (USD)    30.415    31.105    30.785    30.885
# 1       港幣 (HKD)  港幣 (HKD)     3.771     3.987     3.907     3.967
# 2       英鎊 (GBP)  英鎊 (GBP)     38.96     41.08     39.96     40.38
# 3       澳幣 (AUD)  澳幣 (AUD)     22.08     22.86     22.35     22.58
# 4   加拿大幣 (CAD)  加拿大幣 (CAD)     22.82     23.73     23.21     23.43
# 5   新加坡幣 (SGD)  新加坡幣 (SGD)     21.85     22.76     22.34     22.52
# 6   瑞士法郎 (CHF)  瑞士法郎 (CHF)     29.87     31.07     30.53     30.82
# 7       日圓 (JPY)  日圓 (JPY)    0.2623    0.2751    0.2696    0.2736
# 8     南非幣 (ZAR)  南非幣 (ZAR)         -         -      2.13      2.21
# 9     瑞典幣 (SEK)  瑞典幣 (SEK)      3.02      3.54      3.36      3.46
# 10      紐元 (NZD)  紐元 (NZD)     20.52     21.37      20.9      21.1
# 11      泰幣 (THB)  泰幣 (THB)    0.8132    1.0012    0.9218    0.9618
# 12  菲國比索 (PHP)  菲國比索 (PHP)    0.5096    0.6426         -         -
# ...

# %% [markdown]
# ### 正規表示式

# %%
data_clean["幣別"] = data_clean["幣別"].str.extract('\((\w+)\)')
data_clean
# Out:
#      幣別 現今匯率-本行買入 現今匯率-本行賣出 即期匯率-本行買入 即期匯率-本行買出
# 0   USD    30.415    31.105    30.785    30.885
# 1   HKD     3.771     3.987     3.907     3.967
# 2   GBP     38.96     41.08     39.96     40.38
# 3   AUD     22.08     22.86     22.35     22.58
# 4   CAD     22.82     23.73     23.21     23.43
# 5   SGD     21.85     22.76     22.34     22.52
# 6   CHF     29.87     31.07     30.53     30.82
# 7   JPY    0.2623    0.2751    0.2696    0.2736
# 8   ZAR         -         -      2.13      2.21
# 9   SEK      3.02      3.54      3.36      3.46
# 10  NZD     20.52     21.37      20.9      21.1
# 11  THB    0.8132    1.0012    0.9218    0.9618
# 12  PHP    0.5096    0.6426         -         -
# 13  IDR   0.00178   0.00248         -         -
# 14  EUR     34.16      35.5     34.78     35.18
# 15  KRW    0.0256    0.0295         -         -
# 16  VND   0.00095   0.00145         -         -
# 17  MYR     6.264     7.894         -         -
# 18  CNY     4.354     4.516     4.426     4.476

# %%
data_clean.to_csv("currency.csv",encoding = "utf-8-sig")

# %% [markdown]
# ## pandas抓取網站上面的csv
# UCI dataset

# %%
import pandas as pd
url = "http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
iris_data = pd.read_csv(url,header = None)
iris_data
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# 5    5.4  3.9  1.7  0.4     Iris-setosa
# 6    4.6  3.4  1.4  0.3     Iris-setosa
# 7    5.0  3.4  1.5  0.2     Iris-setosa
# 8    4.4  2.9  1.4  0.2     Iris-setosa
# 9    4.9  3.1  1.5  0.1     Iris-setosa
# 10   5.4  3.7  1.5  0.2     Iris-setosa
# 11   4.8  3.4  1.6  0.2     Iris-setosa
# 12   4.8  3.0  1.4  0.1     Iris-setosa
# 13   4.3  3.0  1.1  0.1     Iris-setosa
# 14   5.8  4.0  1.2  0.2     Iris-setosa
# 15   5.7  4.4  1.5  0.4     Iris-setosa
# 16   5.4  3.9  1.3  0.4     Iris-setosa
# 17   5.1  3.5  1.4  0.3     Iris-setosa
# 18   5.7  3.8  1.7  0.3     Iris-setosa
# 19   5.1  3.8  1.5  0.3     Iris-setosa
# 20   5.4  3.4  1.7  0.2     Iris-setosa
# 21   5.1  3.7  1.5  0.4     Iris-setosa
# ...

# %% [markdown]
# #### 物件無法字串使用， .values

# %%
iris_data
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# 5    5.4  3.9  1.7  0.4     Iris-setosa
# 6    4.6  3.4  1.4  0.3     Iris-setosa
# 7    5.0  3.4  1.5  0.2     Iris-setosa
# 8    4.4  2.9  1.4  0.2     Iris-setosa
# 9    4.9  3.1  1.5  0.1     Iris-setosa
# 10   5.4  3.7  1.5  0.2     Iris-setosa
# 11   4.8  3.4  1.6  0.2     Iris-setosa
# 12   4.8  3.0  1.4  0.1     Iris-setosa
# 13   4.3  3.0  1.1  0.1     Iris-setosa
# 14   5.8  4.0  1.2  0.2     Iris-setosa
# 15   5.7  4.4  1.5  0.4     Iris-setosa
# 16   5.4  3.9  1.3  0.4     Iris-setosa
# 17   5.1  3.5  1.4  0.3     Iris-setosa
# 18   5.7  3.8  1.7  0.3     Iris-setosa
# 19   5.1  3.8  1.5  0.3     Iris-setosa
# 20   5.4  3.4  1.7  0.2     Iris-setosa
# 21   5.1  3.7  1.5  0.4     Iris-setosa
# ...

# %%
x = iris_data.iloc[:,0].values
y = iris_data.iloc[:,2].values

# %% [markdown]
# #### 視覺化

# %%
import matplotlib.pyplot as plt
plt.scatter(x[:50],y[:50],color = "red")
plt.scatter(x[50:100],y[50:100],color = "green")
plt.scatter(x[100:150],y[100:150],color = "blue")
plt.show()

# %% [markdown]
# ## 四、AJAX
# 利用ast做成字典

# %%
url = "http://www.twse.com.tw/exchangeReport/STOCK_DAY?response=json&date=20181030&stockNo=2330&_=1542294876211"

# %%
from bs4 import BeautifulSoup
import requests
import ast

# %%
res = requests.get(url)
data = ast.literal_eval(res.text)
data
# Out:
# {'stat': 'OK',
#  'date': '20181030',
#  'title': '107年10月 2330 台積電           各日成交資訊',
#  'fields': ['日期', '成交股數', '成交金額', '開盤價', '最高價', '最低價', '收盤價', '漲跌價差', '成交筆數'],
#  'data': [['107/10/01',
#    '22,409,380',
#    '5,882,532,290',
#    '262.00',
#    '264.00',
#    '261.00',
#    '263.00',
#    '+0.50',
#    '11,914'],
#   ['107/10/02',
#    '38,391,491',
#    '9,926,505,357',
#    '262.00',
#    '263.00',
#    '257.00',
#    '257.50',
#    '-5.50',
#    '17,095'],
#   ['107/10/03',
#    '25,228,536',
#    '6,527,393,860',
#    '257.50',
#    '260.00',
#    '257.00',
#    '260.00',
#    '+2.50',
#    '9,992'],
#   ['107/10/04',
#    '38,009,727',
#    '9,690,178,362',
#    '257.00',
#    '257.50',
#    '254.00',
#    '254.00',
#    '-6.00',
#    '15,094'],
#   ['107/10/05',
#    '40,396,660',
#    '10,101,451,270',
#    '250.00',
#    '253.00',
#    '248.50',
#    '250.00',
#    '-4.00',
#    '16,031'],
#   ['107/10/08',
#    '51,083,958',
#    '12,426,290,240',
#    '245.50',
# ...

# %%
data_price = data["data"]
for i in data_price:
    print(i)
# Out:
# ['107/10/01', '22,409,380', '5,882,532,290', '262.00', '264.00', '261.00', '263.00', '+0.50', '11,914']
# ['107/10/02', '38,391,491', '9,926,505,357', '262.00', '263.00', '257.00', '257.50', '-5.50', '17,095']
# ['107/10/03', '25,228,536', '6,527,393,860', '257.50', '260.00', '257.00', '260.00', '+2.50', '9,992']
# ['107/10/04', '38,009,727', '9,690,178,362', '257.00', '257.50', '254.00', '254.00', '-6.00', '15,094']
# ['107/10/05', '40,396,660', '10,101,451,270', '250.00', '253.00', '248.50', '250.00', '-4.00', '16,031']
# ['107/10/08', '51,083,958', '12,426,290,240', '245.50', '246.50', '241.00', '243.50', '-6.50', '20,745']
# ['107/10/09', '28,933,345', '7,051,600,725', '243.50', '245.00', '242.00', '244.00', '+0.50', '11,743']
# ['107/10/11', '96,033,657', '22,115,862,239', '233.50', '233.50', '227.00', '227.50', '-16.50', '37,543']
# ['107/10/12', '54,439,769', '12,650,322,522', '231.00', '237.00', '229.00', '237.00', '+9.50', '17,980']
# ...

# %%
price = []
for i in data_price:
    print(i[3])
    price.append(float(i[3]))
# Out:
# 262.00
# 262.00
# 257.50
# 257.00
# 250.00
# 245.50
# 243.50
# 233.50
# 231.00
# 234.00
# 229.50
# 241.50
# 238.00
# 231.00
# 232.50
# 232.00
# 230.00
# 220.50
# 223.00
# 223.00
# 221.00
# 228.00

# %%
import matplotlib.pyplot as plt
plt.plot(range(len(data_price)),price)
plt.show()

# %%
url = "https://www.googleapis.com/youtube/v3/channels?part=statistics&id=UCzlp2uazpgM6Tpm4kj9rqSA&key=AIzaSyBR9JpS1_Xy8deq4hnAEufVQD0MEfKHsig"

# %%
from bs4 import BeautifulSoup
import requests

# %%
res = requests.get(url)
#data = BeautifulSoup(res)
res.content
# Out:
# b'{\n "kind": "youtube#channelListResponse",\n "etag": "\\"XI7nbFXulYBIpL0ayR_gDh3eu1k/DYOosrn63CNCpq1eZM-fPiCkezc\\"",\n "pageInfo": {\n  "totalResults": 1,\n  "resultsPerPage": 1\n },\n "items": [\n  {\n   "kind": "youtube#channel",\n   "etag": "\\"XI7nbFXulYBIpL0ayR_gDh3eu1k/NqU7icTxnrdD4fYq8R65mj93q8o\\"",\n   "id": "UCzlp2uazpgM6Tpm4kj9rqSA",\n   "statistics": {\n    "viewCount": "79549054",\n    "commentCount": "0",\n    "subscriberCount": "365038",\n    "hiddenSubscriberCount": false,\n    "videoCount": "84"\n   }\n  }\n ]\n}\n'

# %%
res_to_json = res.json()
print(type(res_to_json))
res_to_json
# Out:
# <class 'dict'>
# {'kind': 'youtube#channelListResponse',
#  'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/DYOosrn63CNCpq1eZM-fPiCkezc"',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1},
#  'items': [{'kind': 'youtube#channel',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/NqU7icTxnrdD4fYq8R65mj93q8o"',
#    'id': 'UCzlp2uazpgM6Tpm4kj9rqSA',
#    'statistics': {'viewCount': '79549054',
#     'commentCount': '0',
#     'subscriberCount': '365038',
#     'hiddenSubscriberCount': False,
#     'videoCount': '84'}}]}

# %%
res_to_json.keys()
# Out:
# dict_keys(['kind', 'etag', 'pageInfo', 'items'])

# %%
res_to_json["items"]
# Out:
# [{'kind': 'youtube#channel',
#   'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/NqU7icTxnrdD4fYq8R65mj93q8o"',
#   'id': 'UCzlp2uazpgM6Tpm4kj9rqSA',
#   'statistics': {'viewCount': '79549054',
#    'commentCount': '0',
#    'subscriberCount': '365038',
#    'hiddenSubscriberCount': False,
#    'videoCount': '84'}}]

# %%
list = [1,2,3,4]
list[1]
# Out:
# 2

# %%
res_to_json["items"][0]['statistics']['viewCount']
# Out:
# '79549054'

# %% [markdown]
# ### print出影片有多少人喜歡多少人不喜歡

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://www.googleapis.com/youtube/v3/videos?part=statistics&id=YbmltsrsWMk&key=AIzaSyBR9JpS1_Xy8deq4hnAEufVQD0MEfKHsig"

# %%
res = requests.get(url)
#data = BeautifulSoup(res)
res.content
# Out:
# b'{\n "kind": "youtube#videoListResponse",\n "etag": "\\"XI7nbFXulYBIpL0ayR_gDh3eu1k/Fxt5a7pf6i550VozLCouxgHMIo4\\"",\n "pageInfo": {\n  "totalResults": 1,\n  "resultsPerPage": 1\n },\n "items": [\n  {\n   "kind": "youtube#video",\n   "etag": "\\"XI7nbFXulYBIpL0ayR_gDh3eu1k/y3zCaYxn6Bh5KVePbQuf0z5oGOQ\\"",\n   "id": "YbmltsrsWMk",\n   "statistics": {\n    "viewCount": "705595",\n    "likeCount": "5489",\n    "dislikeCount": "164",\n    "favoriteCount": "0",\n    "commentCount": "325"\n   }\n  }\n ]\n}\n'

# %%
res_to_json = res.json()
print(type(res_to_json))
res_to_json
# Out:
# <class 'dict'>
# {'kind': 'youtube#videoListResponse',
#  'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/Fxt5a7pf6i550VozLCouxgHMIo4"',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1},
#  'items': [{'kind': 'youtube#video',
#    'etag': '"XI7nbFXulYBIpL0ayR_gDh3eu1k/y3zCaYxn6Bh5KVePbQuf0z5oGOQ"',
#    'id': 'YbmltsrsWMk',
#    'statistics': {'viewCount': '705595',
#     'likeCount': '5489',
#     'dislikeCount': '164',
#     'favoriteCount': '0',
#     'commentCount': '325'}}]}

# %%
like = res_to_json["items"][0]["statistics"]["likeCount"]
dislike = res_to_json["items"][0]["statistics"]["dislikeCount"]
print("有 %d 個人喜歡，有 %d 個人不喜歡" %(int(like),int(dislike)))
# Out:
# 有 5489 個人喜歡，有 164 個人不喜歡

# %% [markdown]
# ### 查看留言

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=YbmltsrsWMk&key=AIzaSyBR9JpS1_Xy8deq4hnAEufVQD0MEfKHsig"

# %%
res = requests.get(url)
#data = BeautifulSoup(res)
#res.content

# %%
res_to_json = res.json()
print(type(res_to_json))
#res_to_json
# Out:
# <class 'dict'>

# %%
res_to_json.keys()
# Out:
# dict_keys(['kind', 'etag', 'nextPageToken', 'pageInfo', 'items'])

# %%
res_to_json["items"][0].keys()
# Out:
# dict_keys(['kind', 'etag', 'id', 'snippet'])

# %%
#res_to_json["items"][0]

# %%
print(len(res_to_json["items"]))
# Out:
# 20

# %%
for i in range(0,len(res_to_json["items"]),1):
    print(res_to_json["items"][i]["snippet"]["topLevelComment"]["snippet"]["textDisplay"])
    #print(i)
# Out:
# 妈耶，一直以为中分是原住民的，这么霸道
# 菊花呢?
# 說好的弄哭女主人呢，差評標題黨
# 花花是不是瘦了很多啊？會回覆我嗎
# 我中分就算饿死，死外面，从这里跳下去，也不会吃你们的。。。真香
# 一直以來都覺得貓是一種過於纖細的動物...
# 你们家的老猫呢？菊花二筒呢？？被你吃了？？？
# 菊花是不是鋪子
# 从最新视频过来的只有我么
# 男主人现在胖了
# 看了新出的影片 特地回来看看中分
# 中分就是那种严肃的搞笑派
# 话说你家猫砂也太少了点吧~
# 和我們家那慫貨一個樣。。。。。
# 看看曾经的大佬，哈哈哈哈哈哈哈哈哈怂爆
# 猫生嘛，总会有那么一段想删掉的视频
# 在b站视频里面不是说 猫咪被抛弃过两次 所以才会很怕生不相信人类 为什么在youtube这里被剪掉了啊 是怕有人骂原来主人吗
# 猥琐发育别浪😂😂😂
# 原諒我在中分拉屎的時候那個bgm笑了一整天
# 猫粮什么牌子的

# %% [markdown]
# #### 進階

# %%
for i in res_to_json["items"]:
    print(i["snippet"]["topLevelComment"]["snippet"]["textDisplay"])
# Out:
# 妈耶，一直以为中分是原住民的，这么霸道
# 菊花呢?
# 說好的弄哭女主人呢，差評標題黨
# 花花是不是瘦了很多啊？會回覆我嗎
# 我中分就算饿死，死外面，从这里跳下去，也不会吃你们的。。。真香
# 一直以來都覺得貓是一種過於纖細的動物...
# 你们家的老猫呢？菊花二筒呢？？被你吃了？？？
# 菊花是不是鋪子
# 从最新视频过来的只有我么
# 男主人现在胖了
# 看了新出的影片 特地回来看看中分
# 中分就是那种严肃的搞笑派
# 话说你家猫砂也太少了点吧~
# 和我們家那慫貨一個樣。。。。。
# 看看曾经的大佬，哈哈哈哈哈哈哈哈哈怂爆
# 猫生嘛，总会有那么一段想删掉的视频
# 在b站视频里面不是说 猫咪被抛弃过两次 所以才会很怕生不相信人类 为什么在youtube这里被剪掉了啊 是怕有人骂原来主人吗
# 猥琐发育别浪😂😂😂
# 原諒我在中分拉屎的時候那個bgm笑了一整天
# 猫粮什么牌子的

# %% [markdown]
# ### 撈全部的留言 (拿100來用，修改page_token)

# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&maxResults=100&pageToken={}&videoId=YbmltsrsWMk&key=AIzaSyBR9JpS1_Xy8deq4hnAEufVQD0MEfKHsig"
page_token = "QURTSl9pM3E4bXowWkJCQVZEUGcxRHFrX0JNczAzRy16dGZ3Rk1jUnQySkpvT2Q5bWNRWWhYaEFrc3poc2FKRWpydkJlSDBRcmpoYXJrRk1kamFfS0VLNERzb1VaVEhBOXNDWFhpeGJFUHBUeDB6UGxVQkRIaDhCMmNpMktvd0Q=%3D"
while True:
    res = requests.get(url.format(page_token))
    res_to_json = res.json()
    if "nextPageToken" in res_to_json.keys():  
        #print(page_token)
        page_token = res_to_json["nextPageToken"]+"%3D"
        for i in res_to_json["items"]:
            print(i["snippet"]["topLevelComment"]["snippet"]["textDisplay"])
    else:
        #print(page_token)
        for i in res_to_json["items"]:
            print(i["snippet"]["topLevelComment"]["snippet"]["textDisplay"])
        break
# Out:
# QURTSl9pM3E4bXowWkJCQVZEUGcxRHFrX0JNczAzRy16dGZ3Rk1jUnQySkpvT2Q5bWNRWWhYaEFrc3poc2FKRWpydkJlSDBRcmpoYXJrRk1kamFfS0VLNERzb1VaVEhBOXNDWFhpeGJFUHBUeDB6UGxVQkRIaDhCMmNpMktvd0Q=%3D
# 你需要錢 我需要人<br />無時間限制打字工作<br />  免會費 押金<br />Wechat:hank20010705<br />LINE:@mtp3596z
# 😍😍😍😘😘😘
# 唉...可惜菊花却走了...
# 他看起來有點肉，就是餓著應該也可以撐幾天吧。😏😜
# 好感動
# 中分你暗恋菊花啊(⊙o⊙)！😮🎂🙇‍♀️
# 好奇，菊花去哪里了？因为我不怎么追这个，但是后来都没看见菊花了
# 以前的怂分，现在的大佬
# 好可愛的中分阿!!!!!!
# 现在最近的视频咋没看到菊花了
# 中分怂过。。。
# 天啊 中分。。。
# 太可愛啦，明顯的冷酷外表但傻憨氣質
# 又回來看中分的慫樣了，哈哈哈 把這拿給牠看牠會不會崩潰？以現在的大佬樣肯定不會承認是牠的🤔
# 結果現在的中分是多麼的霸道XD
# 菊花後來怎么了
# 我只知道：中分，李白，杜甫，还有皮皮猪~菊花是谁呢
# 猫对鱼干了什么？
# 這麼霸道的貓~原來一開始也是很害羞怕生的。
# 像!真像二哈!我是看有橘猫的才看这个,原来霸气大佬以前那么怕胆小,话说另外一个猫(菊花)怎么在其他影片没有看到?
# 中分現在是老大哥，以前也太膽小了Xddd
# 哎呀，是中分老大哥
# 居然在我生日那天發生過這樣的事情(三月二十一日
# 中出
# ......
# 中分：我現在只想吃魚，貓糧拿走
# 现在菊花在哪啊
# 忽然發現皮皮都不會有不吃飯的問題
# 想当年中分还那么胆小的为何现在变这样了
# 中分 : 给我走开 男主人: 嚯呀你还傲娇
# 好怀念菊花<br />呜呜呜
# 看看現在的中分 一個老大樣
# 你们家的猫为什么要割蛋
# 菊花是谁的猫？为什么总是看不它
# 菊花去哪了呢
# 中分真可愛
# 对我来说看起来像奶猫
# 好喜欢中分 中分是啥品种？
# ...

# %% [markdown]
# ### 拿20的留言來用

# %%
url = "https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=YbmltsrsWMk&key=AIzaSyBR9JpS1_Xy8deq4hnAEufVQD0MEfKHsig{}"
page_token = ""
res = requests.get(url)
while True:
    #url = url.format(page_token)
    res = requests.get(url.format(page_token))
    res_to_json = res.json()
    if "nextPageToken" in res_to_json.keys():
        page_token = "&pageToken=" + res_to_json["nextPageToken"] + "%3D"
        print(page_token)
        print("------------------------")
    else:
        break
# Out:
# &pageToken=QURTSl9pMzFFdzQ3SzhqQUxnY0hWYTlWSWI3YmJQMEkwdDBxWi1nOS04dVRObU5kSzVXWldQTXBldDFOSDdEMVhzZFplUURwUnFVT0JOZXNYVk4zeHlwVFBKaF80VFM3UkU0X3MxZXIxakhXOERaVDNJakFxbktwaElVeHBSOWZKWUE=%3D
# ------------------------
# &pageToken=QURTSl9pM1B2VlR0R1FTZk1rZzhhY0dPWmtVODhGel81MkxFMXJVb04yQWZVcXc2Z1pjaDlRSHV5ODlkQV9lcXJyQ1hlVWJFcEN3OWJyWEljWlNnMUhtazF0VVE5VUJ6QkhDWEZwbC1JMFNnUFo3T1FNQ3J4R28wTTZvcG8taUY5SndxRHRhVE8yMzJ5Qnc=%3D
# ------------------------
# &pageToken=QURTSl9pMm5RRWtLYWtPdFYzRWk4T2xvMDJEU1A5dzYwSHNBS0xRVmVQS0NOME9jWEthUjh5T1E4TkFWellvQWc4T2MydGpFVDNHLW9qTVl2cVY3LUFLQ1V6R1JhZ0R2WWZRRlI2ZlU0NlNCa2pxLXRsX2lFS2lVUWRQa2xOeVZiQ25rR25RSTNsMGtWemc=%3D
# ------------------------
# &pageToken=QURTSl9pMjlyWndpWUpwNWYxNjcyaHl6MldHMVpHSnFMZkliR3dqdmNUMkVSR3dVWHBiX3kxYkZ3OWVkb25nLXpRdlRSRTY1dTEzSmJGSkdwODhHRnNUcnQzMGdPYUxzQWlHLW0weEVhU2oxYnBSRjdtSk5hTkwxYnMxdU5pX3hFWktUaUlOcmtKSnhOSHc=%3D
# ------------------------
# ...

# %%
from bs4 import BeautifulSoup
import requests
url = "https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=YbmltsrsWMk&key=AIzaSyBR9JpS1_Xy8deq4hnAEufVQD0MEfKHsig{}"
page_token = ""
res = requests.get(url)
while True:
    res = requests.get(url.format(page_token))
    res_to_json = res.json()
    if "nextPageToken" in res_to_json.keys():        
        page_token = "&pageToken=" + res_to_json["nextPageToken"] + "%3D"
        for i in res_to_json["items"]:
            print(i["snippet"]["topLevelComment"]["snippet"]["textDisplay"])
    else:
        for i in res_to_json["items"]:
            print(i["snippet"]["topLevelComment"]["snippet"]["textDisplay"])
        break
# Out:
# 妈耶，一直以为中分是原住民的，这么霸道
# 菊花呢?
# 說好的弄哭女主人呢，差評標題黨
# 花花是不是瘦了很多啊？會回覆我嗎
# 我中分就算饿死，死外面，从这里跳下去，也不会吃你们的。。。真香
# 一直以來都覺得貓是一種過於纖細的動物...
# 你们家的老猫呢？菊花二筒呢？？被你吃了？？？
# 菊花是不是鋪子
# 从最新视频过来的只有我么
# 男主人现在胖了
# 看了新出的影片 特地回来看看中分
# 中分就是那种严肃的搞笑派
# 话说你家猫砂也太少了点吧~
# 和我們家那慫貨一個樣。。。。。
# 看看曾经的大佬，哈哈哈哈哈哈哈哈哈怂爆
# 猫生嘛，总会有那么一段想删掉的视频
# 在b站视频里面不是说 猫咪被抛弃过两次 所以才会很怕生不相信人类 为什么在youtube这里被剪掉了啊 是怕有人骂原来主人吗
# 猥琐发育别浪😂😂😂
# 原諒我在中分拉屎的時候那個bgm笑了一整天
# 猫粮什么牌子的
# 你需要錢 我需要人<br />無時間限制打字工作<br />  免會費 押金<br />Wechat:hank20010705<br />LINE:@mtp3596z
# 😍😍😍😘😘😘
# 唉...可惜菊花却走了...
# 他看起來有點肉，就是餓著應該也可以撐幾天吧。😏😜
# 好感動
# 中分你暗恋菊花啊(⊙o⊙)！😮🎂🙇‍♀️
# 好奇，菊花去哪里了？因为我不怎么追这个，但是后来都没看见菊花了
# 以前的怂分，现在的大佬
# 好可愛的中分阿!!!!!!
# 现在最近的视频咋没看到菊花了
# 中分怂过。。。
# 天啊 中分。。。
# 太可愛啦，明顯的冷酷外表但傻憨氣質
# 又回來看中分的慫樣了，哈哈哈 把這拿給牠看牠會不會崩潰？以現在的大佬樣肯定不會承認是牠的🤔
# 結果現在的中分是多麼的霸道XD
# 菊花後來怎么了
# 我只知道：中分，李白，杜甫，还有皮皮猪~菊花是谁呢
# 猫对鱼干了什么？
# 這麼霸道的貓~原來一開始也是很害羞怕生的。
# 像!真像二哈!我是看有橘猫的才看这个,原来霸气大佬以前那么怕胆小,话说另外一个猫(菊花)怎么在其他影片没有看到?
# 中分現在是老大哥，以前也太膽小了Xddd
# 哎呀，是中分老大哥
# 居然在我生日那天發生過這樣的事情(三月二十一日
# 中出
# ......
# 中分：我現在只想吃魚，貓糧拿走
# 现在菊花在哪啊
# ...
